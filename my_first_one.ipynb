# %%
4 +5
# Out:
# 9

# %%
import pandas as pd

# %%
data=pd.read_csv('/home/chandu/Documents/github/box_office.csv')
print (data)
# Out:
#          Movie_rating                                         Movie_Name  \
# 0                23.0                                       Yoga Hosers
# 1                67.0                           Last Days in the Desert
# 2                72.0                                         King Jack
# 3                59.0                                   Into the Forest
# 4                59.0                                          Yosemite
# 5                57.0                                   Band of Robbers
# 6                69.0                                          Blue Jay
# 7                55.0                                        Anesthesia
# 8                63.0                             The Eyes of My Mother
# 9                63.0                                    The Ones Below
# 10               74.0                         In Order of Disappearance
# 11               66.0                                      Wedding Doll
# ...

# %%
mod_data= data[:135]
print(mod_data)
# Out:
#      Movie_rating                                         Movie_Name  \
# 0            23.0                                       Yoga Hosers
# 1            67.0                           Last Days in the Desert
# 2            72.0                                         King Jack
# 3            59.0                                   Into the Forest
# 4            59.0                                          Yosemite
# 5            57.0                                   Band of Robbers
# 6            69.0                                          Blue Jay
# 7            55.0                                        Anesthesia
# 8            63.0                             The Eyes of My Mother
# 9            63.0                                    The Ones Below
# 10           74.0                         In Order of Disappearance
# 11           66.0                                      Wedding Doll
# 12           58.0                                  Creative Control
# ...

# %%
print(mod_data ['Genre'])
# Out:
# 0                     Thriller, Fantasy, Horror, Comedy
# 1                             Adventure, Drama, History
# 2                                      Adventure, Drama
# 3                                Sci-Fi, Drama, Thriller
# 4                                                  Drama
# 5                    Adventure, Thriller, Comedy, Crime
# 6                                                 Drama
# 7                                        Drama, Thriller
# 8                                         Drama, Horror
# 9                                               Thriller
# 10                      Action, Thriller, Comedy, Crime
# 11                                                 Drama
# 12                                        Sci-Fi, Drama
# 13                              Thriller, Horror, Comedy
# 14      Adventure, Biography, Drama, Comedy, Music, D...
# 15                                      Drama, Thriller
# 16                                        Drama, Romance
# ...

# %%
for value in mod_data['Genre']:
    print (type(value))
    if(value=='Action'):
        print (value)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# ...

# %%
print (mod_data['Genre'])
# Out:
# 0                     Thriller, Fantasy, Horror, Comedy
# 1                             Adventure, Drama, History
# 2                                      Adventure, Drama
# 3                                Sci-Fi, Drama, Thriller
# 4                                                  Drama
# 5                    Adventure, Thriller, Comedy, Crime
# 6                                                 Drama
# 7                                        Drama, Thriller
# 8                                         Drama, Horror
# 9                                               Thriller
# 10                      Action, Thriller, Comedy, Crime
# 11                                                 Drama
# 12                                        Sci-Fi, Drama
# 13                              Thriller, Horror, Comedy
# 14      Adventure, Biography, Drama, Comedy, Music, D...
# 15                                      Drama, Thriller
# 16                                        Drama, Romance
# ...

# %%
for val in mod_data['Genre']:
    if('Action' in val):
        print (val)
# Out:
# Action, Thriller, Comedy, Crime
# Action, Comedy, Romance
# Action, Drama, Western
# Action, Drama, Thriller, Horror
# Action, Biography, Drama, Sport
# Action, Thriller, Horror, Comedy, Romance
# Action, Biography, Drama, History, War
# Action, Drama, Thriller, Crime
# Action, Comedy
# Action, Biography, Drama, Thriller
# Action, Sci-Fi, Drama, Mystery, Thriller, Crime
# Action, Adventure, Drama, Mystery
# Action, Adventure, Biography, Drama, History, Thriller
# Action, Drama, Thriller, War
# Action, Adventure, Drama, History
# Action, Thriller, Crime
# Action, Drama, History, Thriller, Romance, War
# Action, Comedy
# Action, Adventure, Fantasy
# Action, Drama, Thriller, Crime
# Action, Adventure, Western
# Action, Adventure, Drama, Mystery, Thriller, Crime
# Action, Adventure, Drama, Fantasy
# Action, Adventure, Sci-Fi, Mystery, Thriller, Romance
# Action, Comedy, Crime
# Action, Adventure, Sci-Fi, Drama, Mystery, Thriller, Crime
# Action, Sci-Fi, Fantasy, Comedy
# ...

# %%
mod_data.dtypes
# Out:
# Movie_rating        float64
# Movie_Name           object
# User_Score           object
# Genre                object
# world wide gross    float64
# Domestic gross      float64
# dtype: object

# %%
action=0
adven=0
sci=0
fantasy=0
comedy=0
romance=0
war=0
thriller=0
crime=0
history=0
drama=0
western=0
horror=0
sport=0
biography=0
mystery=0
family=0
music=0
documentary=0
animation=0

for val in mod_data['Genre']:
    if('Action' in val):
        action = action + mod_data['Genre']['world wide gross']
print(action)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc (pandas/_libs/index.c:5085)()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item (pandas/_libs/hashtable.c:13892)()
#
# TypeError: an integer is required
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-e228cce9e431> in <module>()
#      22 for val in mod_data['Genre']:
#      23     if('Action' in val):
# ---> 24         action = action + mod_data['Genre']['world wide gross']
#      25 print(action)
#
# /home/chandu/anaconda3/lib/python3.6/site-packages/pandas/core/series.py in __getitem__(self, key)
#     599         key = com._apply_if_callable(key, self)
#     600         try:
# ...
